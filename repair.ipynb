# %%
# 在 Jupyter cell 中运行这个，直接编辑文件

# 读取文件
with open('spa_analyzer.py', 'r', encoding='utf-8') as f:
    content = f.read()

# 显示前500字符，找到插入位置
print(content[:500])
# Out:
# import mediapipe as mp
# import cv2
# import numpy as np
# from dataclasses import dataclass
# from datetime import datetime
# from typing import List, Dict, Optional, Tuple
# import json
#
# @dataclass
# class PoseMetrics:
#     """姿态指标数据类"""
#     shoulder_balance: float  # 肩部平衡度 (0-100)
#     spine_verticality: float  # 脊柱垂直度
#     hip_alignment: float  # 髋部对齐
#     knee_symmetry: float  # 膝关节对称性
#     overall_score: float  # 综合姿态评分
#     key_points: Dict[str, Tuple[float, float, float]]  # 关键点坐标 (x,y,visibility)
#
# @datacla
